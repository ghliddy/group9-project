# %% [markdown]
# <a href="https://colab.research.google.com/github/ghliddy/group9-project/blob/main/pH_Heatmap_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
ph_data = "https://raw.githubusercontent.com/ghliddy/group9-project/main/New%20Data%20(csv).csv"

csv = ph_data + "https://raw.githubusercontent.com/ghliddy/group9-project/main/New%20Data%20(csv).csv"

df = pd.read_csv(ph_data)

df.head()
# Out:
#        EXPOCODE CRUISE_ID  STNNBR  CASTNO  SAMPNO  BTLNBR  SAMPLE_ID  \
# 0           NaN       NaN     NaN     NaN     NaN     NaN        NaN
# 1  33GG20130609   GU_1302     3.0     3.0   574.0  -999.0   300300.0
# 2  33GG20130609   GU_1302     3.0     3.0   571.0     6.0   300306.0
# 3  33GG20130609   GU_1302     3.0     3.0   572.0     4.0   300304.0
# 4  33GG20130609   GU_1302     3.0     3.0   573.0     2.0   300302.0
#
#         DATE   TIME  LATITUDE  ...  PHSPHT_FLAG_W      NH4 NH4_FLAG_W  \
# 0        NaN    NaN       NaN  ...            NaN  UMOL/KG          2
# 1  9062013.0  22:26    41.105  ...            9.0     -999          9
# 2  9062013.0  22:26    41.105  ...            2.0      0.2          2
# 3  9062013.0  22:26    41.105  ...            2.0      0.5          2
# 4  9062013.0  22:26    41.105  ...            2.0      1.6          2
#
#     TCARBN TCARBN_FLAG_W   ALKALI  ALKALI_FLAG_W PH_TOT  PH_TMP PH_TOT_FLAG_W
# ...

# %%
import numpy as np
df = df.replace(-999., np.NaN)
df
# Out:
#         EXPOCODE CRUISE_ID  STNNBR  CASTNO  SAMPNO  BTLNBR   SAMPLE_ID  \
# 0            NaN       NaN     NaN     NaN     NaN     NaN         NaN
# 1   33GG20130609   GU_1302     3.0     3.0   574.0     NaN    300300.0
# 2   33GG20130609   GU_1302     3.0     3.0   571.0     6.0    300306.0
# 3   33GG20130609   GU_1302     3.0     3.0   572.0     4.0    300304.0
# 4   33GG20130609   GU_1302     3.0     3.0   573.0     2.0    300302.0
# ..           ...       ...     ...     ...     ...     ...         ...
# 88  33GG20130609   GU_1302   151.0   168.0   111.0     4.0  15116804.0
# 89  33GG20130609   GU_1302   151.0   168.0   112.0     2.0  15116802.0
# 90  33GG20130609   GU_1302   154.0   171.0   113.0     6.0  15417106.0
# 91  33GG20130609   GU_1302   154.0   171.0   114.0     4.0  15417104.0
# 92  33GG20130609   GU_1303   154.0   171.0   115.0     2.0  15417102.0
#
#           DATE   TIME  LATITUDE  ...  PHSPHT_FLAG_W      NH4 NH4_FLAG_W  \
# ...

# %%
df = df.drop(columns=['EXPOCODE', 'CRUISE_ID', 'STNNBR', 'CASTNO', 'SAMPNO', 'BTLNBR' ])
df
# Out:
#      SAMPLE_ID        DATE   TIME  LATITUDE  LONGITUDE   DEPTH CTDPRS  \
# 0          NaN         NaN    NaN       NaN        NaN  METERS   DBAR
# 1     300300.0   9062013.0  22:26   41.1050   -70.6183       0      0
# 2     300306.0   9062013.0  22:26   41.1050   -70.6183      43      3
# 3     300304.0   9062013.0  22:26   41.1050   -70.6183      43   21.4
# 4     300302.0   9062013.0  22:26   41.1050   -70.6183      43   39.3
# ..         ...         ...    ...       ...        ...     ...    ...
# 88  15116804.0  23062013.0  19:43   36.6667   -75.1783      35     20
# 89  15116802.0  23062013.0  19:43   36.6667   -75.1783      35     32
# 90  15417106.0  23062013.0  22:54   35.9900   -75.5350      24      3
# 91  15417104.0  23062013.0  22:54   35.9900   -75.5350      24     10
# 92  15417102.0  23062013.0  22:54   35.9900   -75.5350      24     21
#
#      CTDTMP   CTDSAL   CTDOXY  ...  PHSPHT_FLAG_W      NH4  NH4_FLAG_W  \
# ...
